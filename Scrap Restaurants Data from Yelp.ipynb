# %% [markdown]
# ## Use Multiple Pins to find 1000 Restaurants

# %%
import pandas as pd
import numpy as np
import json
import requests
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
#weiwei API key
CLIENT_ID = "dpCAJD_dlXFa-j_e4Wkd2A"
API_KEY = "zXWCW6n0ivUP6TYTG-q72MmKeAaFDo8TF0Mk9E73MxfBui9pJj_VlOVHHWVn1W7kOjy4t_jA84DjaqHG3KuQIbG79atOUjpo4WIACKTtiSrxuwwrh_hEyK4pWleBXHYx"

# %%
#Qihan

# %%
API_HOST = 'https://api.yelp.com' #The API url header
SEARCH_PATH = '/v3/businesses/search' #The path for an API request to find businesses
BUSINESS_PATH = '/v3/businesses/'  # The path to get data for a single business

# %%
def get_restaurants(api_key,location):
    import requests
    data = []
    # Retrive business information from yelp
    # Change UPPER BOUND in offset 
    for offset in range(0,50000,50):
        search_data = {
        'term': "restaurant",
        'location': location.replace(' ', '+'),
        'limit': 50,
        'offset':offset
        }
        url = API_HOST + SEARCH_PATH
        headers = {
            'Authorization': 'Bearer %s' % api_key,
        }
        response = requests.request('GET', url, headers=headers, params=search_data)
        if response.status_code == 200:
            data += response.json().get('businesses')
        elif response.status_code == 400:
            print('400 Bad Request')
            break
    return data

# %% [markdown]
# ### Central Harlem Restaurants

# %%
char = get_restaurants(API_KEY,"Central Harlem, New York, NY")
# Out:
# 400 Bad Request

# %%
char=pd.DataFrame(char)
len(char)
# Out:
# 1000

# %%
#Save 1000 result to 'Central Harlem'
char.to_pickle("./centralharlem_1000.pkl")

# %% [markdown]
# ### Chelsea and Clinton

# %%
chelsea = get_restaurants(API_KEY,"Chelsea and Clinton, New York, NY")
# Out:
# 400 Bad Request

# %%
chelsea=pd.DataFrame(chelsea)
len(chelsea)
# Out:
# 1000

# %%
#Save 1000 result to 'Chelsea and Clinton'
chelsea.to_pickle("./chelsea_1000.pkl")

# %% [markdown]
# ### East Harlem Restaurants

# %%
eharlem = get_restaurants(API_KEY,"East Harlem, New York, NY")
# Out:
# 400 Bad Request

# %%
eharlem=pd.DataFrame(eharlem)
len(eharlem)
# Out:
# 1000

# %%
#Save 1000 result to 'East Harlem'
eharlem.to_pickle("./eastharlem_1000.pkl")

# %% [markdown]
# ### Gramercy Park and Murray Hill Restaurants

# %%
gpmh = get_restaurants(API_KEY,"Gramercy Park and Murray Hill, New York, NY")
# Out:
# 400 Bad Request

# %%
gpmh=pd.DataFrame(gpmh)
len(gpmh)
# Out:
# 1000

# %%
#Save 1000 result to 'Gramercy Park and Murray Hill'
gpmh.to_pickle("./gramercypark_1000.pkl")

# %% [markdown]
# ### Greenwich Village and Soho Restaurants

# %%
green = get_restaurants(API_KEY,"Greenwich Village and Soho, New York, NY")
# Out:
# 400 Bad Request

# %%
green=pd.DataFrame(green)
len(green)
# Out:
# 1000

# %%
#Save 1000 result to 'Greenwich Village and Soho'
green.to_pickle("./greenwich_1000.pkl")

# %% [markdown]
# ### Lower Manhattan Restaurants

# %%
lower1 = get_restaurants(API_KEY,"Lower Manhattan, New York, NY")
# Out:
# 400 Bad Request

# %%
lowerman=pd.DataFrame(lower1)
lowerman
# Out:
#                                                  alias  \
# 0                                      amélie-new-york
# 1                                   upstate-new-york-2
# 2                                  aunt-jakes-new-york
# 3                        burger-and-lobster-new-york-4
# 4                                    lovemama-new-york
# 5                          ipanema-restaurant-new-york
# 6                                 barn-joo-35-new-york
# 7                    boucherie-west-village-new-york-3
# 8                                         bea-new-york
# 9                                      balzem-new-york
# 10                                 chama-mama-new-york
# 11                                   nonono-new-york-6
# 12                           thursday-kitchen-new-york
# 13   carmines-italian-restaurant-times-square-new-y...
# 14                      les-enfants-de-boheme-new-york
# 15                               thai-villa-new-york-2
# ...

# %%
#Save 1000 result to 'Lower Manhattan'
lowerman.to_pickle("./lowermanhattan_1000.pkl")

# %% [markdown]
# ### Lower East Side Restaurants

# %%
lower2 = get_restaurants(API_KEY,"Lower East Side, New York, NY")
# Out:
# 400 Bad Request

# %%
lowereast=pd.DataFrame(lower2)
lowereast
# Out:
#                                          alias  \
# 0               les-enfants-de-boheme-new-york
# 1                              jajaja-new-york
# 2                    the-masalawala-new-york-2
# 3                          the-boil-new-york-3
# 4                        pig-and-khao-new-york
# 5     clinton-street-baking-company-new-york-5
# 6                           tongkatsu-new-york
# 7                          verlaine-new-york-2
# 8                           upstate-new-york-2
# 9                        rabbit-house-new-york
# 10                   excuse-my-french-new-york
# 11          wah-fung-no-1-fast-food-new-york-3
# 12                        la-contenta-new-york
# 13                          set-l-e-s-new-york
# 14                             amélie-new-york
# 15                        claw-daddys-new-york
# 16                   beauty-and-essex-new-york
# 17                      zhen-wei-fang-new-york
# 18                      grand-seoul-new-york-2
# ...

# %%
#Save 1000 result to 'Lower East Side'
lowereast.to_pickle("./lowereast_1000.pkl")

# %% [markdown]
# ### Upper East Side Restaurants

# %%
upper1 = get_restaurants(API_KEY,"Upper East Side, New York, NY")
# Out:
# 400 Bad Request

# %%
uppereast=pd.DataFrame(upper1)
uppereast
# Out:
#                                                  alias  \
# 0                           la-pulperia-ues-new-york-3
# 1                                    grazie-new-york-3
# 2      heidis-house-by-the-side-of-the-road-new-york-2
# 3                                         uva-new-york
# 4                      the-drunken-munkey-ues-new-york
# 5                                     up-thai-new-york
# 6                  agora-turkish-restaurant-new-york-2
# 7      boqueria-spanish-tapas-upper-east-side-new-york
# 8                              pitchounette81-new-york
# 9                          tri-dim-shanghai-new-york-2
# 10                       jones-wood-foundry-new-york-2
# 11                     thep-thai-restaurant-new-york-5
# 12                     suki-ichiro-restaurant-new-york
# 13                          davids-cuban-cafe-new-york
# 14                                   pascalou-new-york
# 15        sumela-mediterranean-cafe-and-grill-new-york
# ...

# %%
#Save 1000 result to 'Upper East Side'
uppereast.to_pickle("./uppereast_1000.pkl")

# %% [markdown]
# ### Upper West Side Restaurants

# %%
upper2 = get_restaurants(API_KEY,"Upper West Side, New York, NY")
# Out:
# 400 Bad Request

# %%
upperwest=pd.DataFrame(upper2)
upperwest
# Out:
#                                                  alias  \
# 0                              jacobs-pickles-new-york
# 1                               osteria-cotta-new-york
# 2                                 jin-ramen-new-york-3
# 3                          the-milling-room-new-york-2
# 4                                     leyla-new-york-4
# 5            lokal-83-mediterranean-kitchen-new-york-2
# 6                                  calle-ocho-new-york
# 7                                    amelie-new-york-2
# 8                               maison-pickle-new-york
# 9                                      bustan-new-york
# 10                              han-dynasty-new-york-4
# 11                               sushi-yasaka-new-york
# 12                            burke-and-wills-new-york
# 13                     ella-kitchen-and-bar-new-york-2
# 14                                      tessa-new-york
# 15                                       kefi-new-york
# ...

# %%
#Save 1000 result to 'Upper West Side'
upperwest.to_pickle("./upperwest_1000.pkl")

# %% [markdown]
# ### Inwood and Washington Heights Restaurants

# %%
wsh = get_restaurants(API_KEY,"Inwood and Washington Heights, New York, NY")
# Out:
# 400 Bad Request

# %%
wsh=pd.DataFrame(wsh)
wsh
# Out:
#                                        alias  \
# 0                 the-pandering-pig-new-york
# 1                          saggio-new-york-2
# 2                 rincon-mexicano-new-york-2
# 3                            raices-new-york
# 4                     tampopo-ramen-new-york
# 5           la-cabana-salvadoreña-new-york-2
# 6                tryon-public-house-new-york
# 7               grito-mexican-grill-new-york
# 8                       terravita-new-york-3
# 9                     beans-and-vines-inwood
# 10             inwood-bar-and-grill-new-york
# 11                    locksmith-bar-new-york
# 12             malecon-restaurant-new-york-2
# 13                     manolo-tapas-new-york
# 14                           bar180-new-york
# 15           brown-sugar-restaurant-new-york
# 16                         pocion-new-york-6
# 17                      le-chéile-new-york-2
# 18                   suyo-gastrofusion-bronx
# 19               zoe-restaurant-bar-new-york
# ...

# %%
#Save 1000 result to 'Inwood and Washington Heights'
wsh.to_pickle("./inwoodwashington_472.pkl")

# %% [markdown]
# ### Combine Restaurants based on all 10 pins

# %%
# Merge all 10 dataframes
df = pd.concat([char,chelsea,eharlem,gpmh,green,lowerman,lowereast,uppereast,upperwest,wsh]).drop_duplicates(subset='id').reset_index(drop=True)
len(df.id.unique())
# Out:
# 5199

# %% [markdown]
# ### Save As Final Restaurant DataFrame

# %%
# Save all 5199 as our 
df.to_pickle("./final_business_5199.pkl")
